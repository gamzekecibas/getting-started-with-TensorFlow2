# %% [markdown]
# # Course Project Week5
# ## Dataset: [SVHN dataset](http://ufldl.stanford.edu/housenumbers/)
# ### Gamze Keçibaş
# ---
# ### CONTENT
#
# - **Step 01.** Import libraries
# - **Step 02.** Load and preprocess data
# - **Step 03.** Build the first model
# - **Step 04.** Fit the model to the training data
# - **Step 05.** Plot learning curves
# - **Step 06.** Reducing overfitting in the model
# - **Step 07.** Instantiate, compile and train the model
# - **Step 08.** Plot the learning curves of regularized model
# - **Step 09.** Implement callback objects
# - **Step 10.** Final learning curves
# - **Step 11.** Model evaluation

# %%
import tensorflow as tf
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt
import random

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
# Run this cell to load the dataset

train = loadmat('train_32x32.mat')
test = loadmat('test_32x32.mat')

# %%
train_data= train['X']
train_label= train['y']
test_data= test['X']
test_label= test['y']

train_data = np.moveaxis(train_data, -1, 0)
test_data = np.moveaxis(test_data, -1, 0)
train_label = np.where(train_label==10, 0, train_label)
test_label = np.where(test_label==10, 0, test_label)

print(train_data.shape)
print(test_data.shape)
# Out:
# (73257, 32, 32, 3)
# (26032, 32, 32, 3)

# %%
fig_rnd= np.random.randint(0,len(train_data),10)

for ind in fig_rnd:
    train_fig= np.array(train_data[ind,:,:,:])
    plt.figure()
    plt.imshow(train_fig)

# %%
# Gray scale
gtrain_data= np.mean(train_data, -1, keepdims=False)
gtest_data= np.mean(test_data, -1, keepdims=False)

for ind in fig_rnd:
    train_fig= np.array(gtrain_data[ind,:,:])
    plt.figure()
    plt.imshow(train_fig)

# %% [markdown]
#  MLP neural network classifier
# * Build an MLP classifier model using the Sequential API. Your model should use only Flatten and Dense layers, with the final layer having a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different MLP architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 4 or 5 layers._

# %%
model_mlp = Sequential([ Flatten(input_shape=train_data[0].shape), Dense(256, activation='relu'),
                        Dense(128, activation='relu'), Dense(128, activation='relu'),
                        Dense(10, activation='softmax')])
model_mlp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               786688
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 837,386
# Trainable params: 837,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp_path = 'Checkpoint/Best_model'
cp = ModelCheckpoint(cp_path,
                     save_best_only=True,
                     save_weights_only=True,
                     verbose=False,
                     save_freq='epoch',
                     monitor='val_loss',
                     mode='min')
EarlyStop = EarlyStopping(monitor='val_loss', mode='min', patience=2)

# %%
model_mlp.compile(optimizer= 'adam', loss=tf.keras.losses.sparse_categorical_crossentropy, metrics= ['accuracy'])

# %%
history_mlp= model_mlp.fit(train_data, train_label, epochs=20, batch_size=32,
                           verbose=True, validation_split=0.2, callbacks=[cp, EarlyStop])
# Out:
# Epoch 1/20
# 1832/1832 [==============================] - 8s 4ms/step - loss: 8.8076 - accuracy: 0.1689 - val_loss: 2.3369 - val_accuracy: 0.1413
# Epoch 2/20
# 1832/1832 [==============================] - 7s 4ms/step - loss: 1.9220 - accuracy: 0.3520 - val_loss: 1.6016 - val_accuracy: 0.4778
# Epoch 3/20
# 1832/1832 [==============================] - 7s 4ms/step - loss: 1.6255 - accuracy: 0.4702 - val_loss: 1.4563 - val_accuracy: 0.5298
# Epoch 4/20
# 1832/1832 [==============================] - 7s 4ms/step - loss: 1.4939 - accuracy: 0.5194 - val_loss: 1.4744 - val_accuracy: 0.5135
# Epoch 5/20
# 1832/1832 [==============================] - 8s 4ms/step - loss: 1.4120 - accuracy: 0.5482 - val_loss: 1.4705 - val_accuracy: 0.5259

# %%
plt.plot(history_mlp.history['loss'],'b.')
plt.plot(history_mlp.history['val_loss'],'b-')
plt.title("Loss for MLP Model")
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()

# %%
plt.plot(history_mlp.history['accuracy'],'r.')
plt.plot(history_mlp.history['val_accuracy'],'r-')
plt.title("Accuracy for MLP")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.show()

# %%
test_loss_mlp, test_accuracy_mlp = model_mlp.evaluate(test_data, test_label, verbose=False)
print(f"Test Loss is {test_loss_mlp} for MLP.")
print(f"Test Accuracy is {test_accuracy_mlp} for MLP.")
# Out:
# Test Loss is 1.6243284940719604 for MLP.
# Test Accuracy is 0.5006530284881592 for MLP.

# %% [markdown]
# ## 3. CNN neural network classifier
# * Build a CNN classifier model using the Sequential API. Your model should use the Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense and Dropout layers. The final layer should again have a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different CNN architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 2 or 3 convolutional layers and 2 fully connected layers.)_
# * The CNN model should use fewer trainable parameters than your MLP model.
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * You should aim to beat the MLP model performance with fewer parameters!
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
model_cnn = Sequential([ 
    Conv2D(16, (3,3), padding='same', activation='relu', input_shape=train_data[0].shape),
    MaxPooling2D((2,2)), 
    Conv2D(16, (3,3), activation='relu'),
    MaxPooling2D((2,2)), 
    Conv2D(16, (3,3), padding='same', activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')]
)
model_cnn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 16)        2320
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 16)          2320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 3, 3, 16)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 144)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               18560
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                650
# =================================================================
# Total params: 32,554
# Trainable params: 32,554
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp_path_cnn = 'CNN_Checkpoint/Best_model'
cp_cnn = ModelCheckpoint(cp_path_cnn,
                     save_best_only=True,
                     save_weights_only=True,
                     verbose=False,
                     save_freq='epoch',
                     monitor='val_loss',
                     mode='min')
EarlyStop_cnn = EarlyStopping(monitor='val_loss', mode='min', patience=2)
CB_cnn= [cp_cnn, EarlyStop_cnn]

# %%
model_cnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_cnn = model_cnn.fit(train_data, train_label, epochs=20, batch_size=64,
                        verbose=True, validation_split=0.2, callbacks=CB_cnn)
# Out:
# Epoch 1/20
# 916/916 [==============================] - 27s 29ms/step - loss: 2.1581 - accuracy: 0.2565 - val_loss: 1.4994 - val_accuracy: 0.5110
# Epoch 2/20
# 916/916 [==============================] - 28s 31ms/step - loss: 1.2232 - accuracy: 0.6111 - val_loss: 0.9761 - val_accuracy: 0.6949
# Epoch 3/20
# 916/916 [==============================] - 27s 29ms/step - loss: 0.8689 - accuracy: 0.7318 - val_loss: 0.7230 - val_accuracy: 0.7826
# Epoch 4/20
# 916/916 [==============================] - 27s 30ms/step - loss: 0.7377 - accuracy: 0.7739 - val_loss: 0.6441 - val_accuracy: 0.8046
# Epoch 5/20
# 916/916 [==============================] - 27s 29ms/step - loss: 0.6569 - accuracy: 0.8008 - val_loss: 0.5994 - val_accuracy: 0.8193
# Epoch 6/20
# 916/916 [==============================] - 27s 29ms/step - loss: 0.6145 - accuracy: 0.8136 - val_loss: 0.5534 - val_accuracy: 0.8324
# Epoch 7/20
# 916/916 [==============================] - 26s 29ms/step - loss: 0.5788 - accuracy: 0.8260 - val_loss: 0.5819 - val_accuracy: 0.8206
# Epoch 8/20
# 916/916 [==============================] - 26s 28ms/step - loss: 0.5569 - accuracy: 0.8317 - val_loss: 0.5021 - val_accuracy: 0.8498
# Epoch 9/20
# 916/916 [==============================] - 27s 29ms/step - loss: 0.5305 - accuracy: 0.8399 - val_loss: 0.5143 - val_accuracy: 0.8451
# Epoch 10/20
# 916/916 [==============================] - 26s 28ms/step - loss: 0.5116 - accuracy: 0.8463 - val_loss: 0.4957 - val_accuracy: 0.8523
# Epoch 11/20
# 916/916 [==============================] - 27s 30ms/step - loss: 0.4956 - accuracy: 0.8506 - val_loss: 0.4882 - val_accuracy: 0.8520
# Epoch 12/20
# 916/916 [==============================] - 26s 28ms/step - loss: 0.4854 - accuracy: 0.8529 - val_loss: 0.5134 - val_accuracy: 0.8492
# Epoch 13/20
# 916/916 [==============================] - 27s 30ms/step - loss: 0.4670 - accuracy: 0.8596 - val_loss: 0.4662 - val_accuracy: 0.8604
# Epoch 14/20
# 916/916 [==============================] - 26s 28ms/step - loss: 0.4642 - accuracy: 0.8597 - val_loss: 0.5104 - val_accuracy: 0.8468
# Epoch 15/20
# 916/916 [==============================] - 26s 29ms/step - loss: 0.4558 - accuracy: 0.8636 - val_loss: 0.4709 - val_accuracy: 0.8608

# %%
plt.figure()
plt.plot(history_cnn.history['loss'],'b.')
plt.plot(history_cnn.history['val_loss'], 'b-')
plt.title("Loss of CNN")
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()

plt.figure()
plt.plot(history_cnn.history['accuracy'],'r.')
plt.plot(history_cnn.history['val_accuracy'],'r-')
plt.title("Accuracy of CNN")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.show()

# %%
test_loss_cnn, test_accuracy_cnn = model_cnn.evaluate(test_data, test_label, verbose=False)
print(f"Test Loss is {test_loss_cnn}")
print(f"Test Accuracy is {test_accuracy_cnn}")
# Out:
# Test Loss is 0.49100184440612793
# Test Accuracy is 0.8597495555877686

# %%
model_mlp.load_weights('Checkpoint/Best_model')

# %%
model_cnn.load_weights('CNN_Checkpoint/Best_model')

# %%
num_test_images = test_data.shape[0]

random_inx = np.random.choice(num_test_images, 5)
random_test_images = test_data[random_inx, ...]
random_test_labels = test_label[random_inx, ...]

predictions = model_mlp.predict(random_test_images)

fig, axes = plt.subplots(5, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, random_test_images, random_test_labels)):
    axes[i, 0].imshow(np.squeeze((image * 255).astype(np.uint8)))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(len(prediction)), prediction)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Categorical distribution. Model prediction: {np.argmax(prediction)}")
    
plt.show()

# %%
# For CNN
num_test_images = test_data.shape[0]

random_inx = np.random.choice(num_test_images, 5)
random_test_images = test_data[random_inx, ...]
random_test_labels = test_label[random_inx, ...]

predictions = model_cnn.predict(random_test_images)

fig, axes = plt.subplots(5, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, random_test_images, random_test_labels)):
    axes[i, 0].imshow(np.squeeze((image * 255).astype(np.uint8)))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(10., -1.5, f'Digit {label}')
    axes[i, 1].bar(np.arange(len(prediction)), prediction)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Categorical distribution. Model prediction: {np.argmax(prediction)}")
    
plt.show()
