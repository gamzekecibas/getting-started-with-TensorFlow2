# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Data pipeline with Keras and tf.data

# %% [markdown]
# ### Instructions
#
# In this notebook, you will implement a data processing pipeline using tools from both Keras and the tf.data module. You will use the `ImageDataGenerator` class in the tf.keras module to feed a network with training and test images from a local directory containing a subset of the LSUN dataset, and train the model both with and without data augmentation. You will then use the `map` and `filter` functions of the `Dataset` class with the CIFAR-100 dataset to train a network to classify a processed subset of the images.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook

import tensorflow as tf
from tensorflow.keras.datasets import cifar100
import numpy as np
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input,Dense,Flatten,Conv2D,MaxPooling2D,Dropout
from tensorflow.keras.models import  Sequential, Model

# %% [markdown]
# ### Part 1: tf.keras
# <table><tr>
# <td> <img src="data/lsun/church.png" alt="Church" style="height: 210px;"/>  </td>
# <td> <img src="data/lsun/classroom.png" alt="Classroom" style="height: 210px;"/> </td>
#     <td> <img src="data/lsun/conference_room.png" alt="Conference Room" style="height: 210px;"/> </td>
# </tr></table>
#
# #### The LSUN Dataset
#
# In the first part of this assignment, you will use a subset of the [LSUN dataset](https://www.yf.io/p/lsun). This is a large-scale image dataset with 10 scene and 20 object categories. A subset of the LSUN dataset has been provided, and has already been split into training and test sets. The three classes included in the subset are `church_outdoor`, `classroom` and `conference_room`.
#
# * F. Yu, A. Seff, Y. Zhang, S. Song, T. Funkhouser and J. Xia. "LSUN: Construction of a Large-scale Image Dataset using Deep Learning with Humans in the Loop". arXiv:1506.03365, 10 Jun 2015
#
# Your goal is to use the Keras preprocessing tools to construct a data ingestion and augmentation pipeline to train a neural network to classify the images into the three classes.

# %%
# Save the directory locations for the training, validation and test sets

train_dir = 'data/lsun/train'
valid_dir = 'data/lsun/valid'
test_dir = 'data/lsun/test'

# %% [markdown]
# #### Create a data generator using the ImageDataGenerator class

# %% [markdown]
# You should first write a function that creates an `ImageDataGenerator` object, which rescales the image pixel values by a factor of 1/255.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_ImageDataGenerator():
    """
    This function should return an instance of the ImageDataGenerator class.
    This instance should be set up to rescale the data with the above scaling factor.
    """
    return ImageDataGenerator(rescale = 1/255)

# %%
# Call the function to get an ImageDataGenerator as specified

image_gen = get_ImageDataGenerator()

# %% [markdown]
# You should now write a function that returns a generator object that will yield batches of images and labels from the training and test set directories. The generators should:
#
# * Generate batches of size 20.
# * Resize the images to 64 x 64 x 3.
# * Return one-hot vectors for labels. These should be encoded as follows:
#     * `classroom` $\rightarrow$ `[1., 0., 0.]`
#     * `conference_room` $\rightarrow$ `[0., 1., 0.]`
#     * `church_outdoor` $\rightarrow$ `[0., 0., 1.]`
# * Pass in an optional random `seed` for shuffling (this should be passed into the `flow_from_directory` method).
#
# **Hint:** you may need to refer to the [documentation](https://keras.io/preprocessing/image/#imagedatagenerator-class) for the `ImageDataGenerator`.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.

def get_generator(image_data_generator, directory, seed=None):
    """
    This function takes an ImageDataGenerator object in the first argument and a 
    directory path in the second argument.
    It should use the ImageDataGenerator to return a generator object according 
    to the above specifications. 
    The seed argument should be passed to the flow_from_directory method.
    """
    return image_data_generator.flow_from_directory(directory,target_size=(64,64), 
                                             classes=['classroom','conference_room','church_outdoor'],
                                             class_mode="categorical",
                                             batch_size=20,seed=seed
                                            )

# %%
# Run this cell to define training and validation generators

train_generator = get_generator(image_gen, train_dir)
valid_generator = get_generator(image_gen, valid_dir)
# Out:
# Found 300 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %% [markdown]
# We are using a small subset of the dataset for demonstrative purposes in this assignment.

# %% [markdown]
# #### Display sample images and labels from the training set
#
# The following cell depends on your function `get_generator` to be implemented correctly. If it raises an error, go back and check the function specifications carefully.

# %%
# Display a few images and labels from the training set

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])
lsun_classes = ['classroom', 'conference_room', 'church_outdoor']

plt.figure(figsize=(16,10))
for i in range(20):
    ax = plt.subplot(4, 5, i+1)
    plt.imshow(batch_images[i])
    plt.title(lsun_classes[np.where(batch_labels[i] == 1.)[0][0]])
    plt.axis('off')

# %%
# Reset the training generator

train_generator = get_generator(image_gen, train_dir)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Build the neural network model
#
# You will now build and compile a convolutional neural network classifier. Using the functional API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to define the Input layer.
# * The first hidden layer should be a Conv2D layer with 8 filters, a 8x8 kernel size.
# * The second hidden layer should be a MaxPooling2D layer with a 2x2 pooling window size.
# * The third hidden layer should be a Conv2D layer with 4 filters, a 4x4 kernel size.
# * The fourth hidden layer should be a MaxPooling2D layer with a 2x2 pooling window size.
# * This should be followed by a Flatten layer, and then a Dense layer with 16 units and ReLU activation.
# * The final layer should be a Dense layer with 3 units and softmax activation.
# * All Conv2D layers should use `"SAME"` padding and a ReLU activation function.
#
# In total, the network should have 8 layers. The model should then be compiled with the Adam optimizer with learning rate 0.0005, categorical cross entropy loss, and the 'accuracy' metric.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.

def get_model(input_shape):
    """
    This function should build and compile a CNN model according to the above specification,
    using the functional API. Your function should return the model.
    """
    model_input = Input(shape = input_shape)
    conv1 = Conv2D(8, 8, activation = 'relu', padding = 'SAME')(model_input)
    pool1 = MaxPooling2D(2)(conv1)
    conv2 = Conv2D(4, 4, activation = 'relu', padding = 'SAME')(pool1)
    pool2 = MaxPooling2D(2)(conv2)
    flat = Flatten()(pool2)
    dense1 = Dense(16, activation = 'softmax')(flat)
    model_output = Dense(3, activation = 'softmax')(dense1)
    
    model = Model(inputs = model_input, outputs = model_output)
    
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 5e-4),
                 loss = tf.keras.losses.categorical_crossentropy,
                 metrics = [tf.keras.metrics.categorical_accuracy])
    return model

# %%
# Build and compile the model, print the model summary

lsun_model = get_model((64, 64, 3))
lsun_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 8)         1544
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 4)         516
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 4)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 16)                16400
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the neural network model
#
# You should now write a function to train the model for a specified number of epochs (specified in the `epochs` argument). The function takes a `model` argument, as well as `train_gen` and `valid_gen` arguments for the training and validation generators respectively, which you should use for training and validation data in the training run. You should also use the following callbacks:
#
# * An `EarlyStopping` callback that monitors the validation accuracy and has patience set to 10.
# * A `ReduceLROnPlateau` callback that monitors the validation loss and has the factor set to 0.5 and minimum learning set to 0.0001
#
# Your function should return the training history.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.

def train_model(model, train_gen, valid_gen, epochs):
    """
    This function should define the callback objects specified above, and then use the
    train_gen and valid_gen generator object arguments to train the model for the (maximum) 
    number of epochs specified in the function argument, using the defined callbacks.
    The function should return the training history.
    """
    early_stopping = tf.keras.callbacks.EarlyStopping(patience = 10)
    lr_reduce = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_acc',
                                                    factor = 0.5,
                                                    min_lr = 1e-4)
    
    model_callbacks = [early_stopping, lr_reduce]
    
    history = model.fit_generator(train_gen, epochs = epochs,
                                 validation_data = valid_gen,
                                 callbacks = model_callbacks)
    return history

# %%
# Train the model for (maximum) 50 epochs

history = train_model(lsun_model, train_generator, valid_generator, epochs=50)
# Out:
# Epoch 1/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0964 - categorical_accuracy: 0.3536WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 805ms/step - loss: 1.0969 - categorical_accuracy: 0.3467 - val_loss: 1.0832 - val_categorical_accuracy: 0.3333
# Epoch 2/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0797 - categorical_accuracy: 0.4000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 660ms/step - loss: 1.0777 - categorical_accuracy: 0.4267 - val_loss: 1.0640 - val_categorical_accuracy: 0.5333
# Epoch 3/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0543 - categorical_accuracy: 0.5786WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 700ms/step - loss: 1.0543 - categorical_accuracy: 0.5700 - val_loss: 1.0244 - val_categorical_accuracy: 0.5833
# Epoch 4/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0167 - categorical_accuracy: 0.5714WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 1.0132 - categorical_accuracy: 0.5733 - val_loss: 1.0056 - val_categorical_accuracy: 0.5000
# Epoch 5/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9641 - categorical_accuracy: 0.6071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 680ms/step - loss: 0.9622 - categorical_accuracy: 0.6100 - val_loss: 0.9838 - val_categorical_accuracy: 0.5333
# Epoch 6/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9461 - categorical_accuracy: 0.6107WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 713ms/step - loss: 0.9497 - categorical_accuracy: 0.6067 - val_loss: 0.9599 - val_categorical_accuracy: 0.5833
# Epoch 7/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9091 - categorical_accuracy: 0.6929WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.9095 - categorical_accuracy: 0.6967 - val_loss: 0.9413 - val_categorical_accuracy: 0.6000
# Epoch 8/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9050 - categorical_accuracy: 0.6571WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 700ms/step - loss: 0.9024 - categorical_accuracy: 0.6667 - val_loss: 0.9445 - val_categorical_accuracy: 0.5917
# Epoch 9/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8824 - categorical_accuracy: 0.7250WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 687ms/step - loss: 0.8803 - categorical_accuracy: 0.7300 - val_loss: 0.9260 - val_categorical_accuracy: 0.6167
# Epoch 10/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8781 - categorical_accuracy: 0.7214WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.8708 - categorical_accuracy: 0.7333 - val_loss: 0.9265 - val_categorical_accuracy: 0.6000
# Epoch 11/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8391 - categorical_accuracy: 0.7464WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 680ms/step - loss: 0.8481 - categorical_accuracy: 0.7367 - val_loss: 0.9184 - val_categorical_accuracy: 0.6000
# Epoch 12/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8452 - categorical_accuracy: 0.7286WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 713ms/step - loss: 0.8440 - categorical_accuracy: 0.7267 - val_loss: 0.9357 - val_categorical_accuracy: 0.5667
# Epoch 13/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8575 - categorical_accuracy: 0.7214WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 686ms/step - loss: 0.8574 - categorical_accuracy: 0.7233 - val_loss: 0.9120 - val_categorical_accuracy: 0.6250
# Epoch 14/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8285 - categorical_accuracy: 0.7286WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 680ms/step - loss: 0.8298 - categorical_accuracy: 0.7300 - val_loss: 0.9087 - val_categorical_accuracy: 0.6250
# Epoch 15/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8013 - categorical_accuracy: 0.7714WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 700ms/step - loss: 0.8051 - categorical_accuracy: 0.7633 - val_loss: 0.8992 - val_categorical_accuracy: 0.5917
# Epoch 16/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7922 - categorical_accuracy: 0.7893WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 687ms/step - loss: 0.7922 - categorical_accuracy: 0.7867 - val_loss: 0.8926 - val_categorical_accuracy: 0.6250
# Epoch 17/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7757 - categorical_accuracy: 0.7929WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.7821 - categorical_accuracy: 0.7833 - val_loss: 0.9000 - val_categorical_accuracy: 0.6250
# Epoch 18/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7648 - categorical_accuracy: 0.8071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.7682 - categorical_accuracy: 0.7967 - val_loss: 0.8921 - val_categorical_accuracy: 0.6167
# Epoch 19/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7440 - categorical_accuracy: 0.8393WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 700ms/step - loss: 0.7527 - categorical_accuracy: 0.8233 - val_loss: 0.8891 - val_categorical_accuracy: 0.6167
# Epoch 20/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7592 - categorical_accuracy: 0.7821WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 686ms/step - loss: 0.7585 - categorical_accuracy: 0.7833 - val_loss: 0.8916 - val_categorical_accuracy: 0.6083
# Epoch 21/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7556 - categorical_accuracy: 0.8000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 700ms/step - loss: 0.7521 - categorical_accuracy: 0.8000 - val_loss: 0.8892 - val_categorical_accuracy: 0.6167
# Epoch 22/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7276 - categorical_accuracy: 0.8143WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.7233 - categorical_accuracy: 0.8233 - val_loss: 0.8846 - val_categorical_accuracy: 0.6167
# Epoch 23/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7373 - categorical_accuracy: 0.8071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 687ms/step - loss: 0.7354 - categorical_accuracy: 0.8133 - val_loss: 0.8923 - val_categorical_accuracy: 0.6167
# Epoch 24/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7243 - categorical_accuracy: 0.8036WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 713ms/step - loss: 0.7294 - categorical_accuracy: 0.8000 - val_loss: 0.8821 - val_categorical_accuracy: 0.6250
# Epoch 25/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7004 - categorical_accuracy: 0.8393WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 687ms/step - loss: 0.6995 - categorical_accuracy: 0.8433 - val_loss: 0.8857 - val_categorical_accuracy: 0.5917
# Epoch 26/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7024 - categorical_accuracy: 0.8321WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 686ms/step - loss: 0.6935 - categorical_accuracy: 0.8400 - val_loss: 0.8950 - val_categorical_accuracy: 0.6250
# Epoch 27/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7247 - categorical_accuracy: 0.8071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.7280 - categorical_accuracy: 0.8000 - val_loss: 0.8754 - val_categorical_accuracy: 0.6333
# Epoch 28/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6923 - categorical_accuracy: 0.8286WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 687ms/step - loss: 0.6890 - categorical_accuracy: 0.8300 - val_loss: 0.9009 - val_categorical_accuracy: 0.6083
# Epoch 29/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6878 - categorical_accuracy: 0.8393WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 687ms/step - loss: 0.6988 - categorical_accuracy: 0.8267 - val_loss: 0.8872 - val_categorical_accuracy: 0.6083
# Epoch 30/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6834 - categorical_accuracy: 0.8464WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 700ms/step - loss: 0.6753 - categorical_accuracy: 0.8533 - val_loss: 0.8869 - val_categorical_accuracy: 0.6250
# Epoch 31/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6939 - categorical_accuracy: 0.8214WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 680ms/step - loss: 0.6936 - categorical_accuracy: 0.8233 - val_loss: 0.8793 - val_categorical_accuracy: 0.6417
# Epoch 32/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6926 - categorical_accuracy: 0.8179WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 713ms/step - loss: 0.6965 - categorical_accuracy: 0.8133 - val_loss: 0.8935 - val_categorical_accuracy: 0.6250
# Epoch 33/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6440 - categorical_accuracy: 0.8571WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.6581 - categorical_accuracy: 0.8467 - val_loss: 0.8739 - val_categorical_accuracy: 0.6333
# Epoch 34/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6428 - categorical_accuracy: 0.8643WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.6415 - categorical_accuracy: 0.8667 - val_loss: 0.8751 - val_categorical_accuracy: 0.6250
# Epoch 35/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6560 - categorical_accuracy: 0.8429WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 680ms/step - loss: 0.6461 - categorical_accuracy: 0.8533 - val_loss: 0.8707 - val_categorical_accuracy: 0.6417
# Epoch 36/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6323 - categorical_accuracy: 0.8679WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 699ms/step - loss: 0.6299 - categorical_accuracy: 0.8700 - val_loss: 0.8755 - val_categorical_accuracy: 0.6250
# Epoch 37/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6198 - categorical_accuracy: 0.8714WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 680ms/step - loss: 0.6180 - categorical_accuracy: 0.8733 - val_loss: 0.8755 - val_categorical_accuracy: 0.6333
# Epoch 38/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6081 - categorical_accuracy: 0.8750WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.6221 - categorical_accuracy: 0.8633 - val_loss: 0.8690 - val_categorical_accuracy: 0.6333
# Epoch 39/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6047 - categorical_accuracy: 0.8857WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 687ms/step - loss: 0.6077 - categorical_accuracy: 0.8833 - val_loss: 0.8707 - val_categorical_accuracy: 0.6417
# Epoch 40/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5927 - categorical_accuracy: 0.8929WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.5933 - categorical_accuracy: 0.8900 - val_loss: 0.8693 - val_categorical_accuracy: 0.6417
# Epoch 41/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5868 - categorical_accuracy: 0.8857WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 680ms/step - loss: 0.5896 - categorical_accuracy: 0.8833 - val_loss: 0.8636 - val_categorical_accuracy: 0.6333
# Epoch 42/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6016 - categorical_accuracy: 0.8786WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.5931 - categorical_accuracy: 0.8867 - val_loss: 0.8670 - val_categorical_accuracy: 0.6333
# Epoch 43/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5712 - categorical_accuracy: 0.9071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 700ms/step - loss: 0.5786 - categorical_accuracy: 0.9000 - val_loss: 0.8625 - val_categorical_accuracy: 0.6333
# Epoch 44/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5787 - categorical_accuracy: 0.8821WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 713ms/step - loss: 0.5715 - categorical_accuracy: 0.8900 - val_loss: 0.8615 - val_categorical_accuracy: 0.6583
# Epoch 45/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5705 - categorical_accuracy: 0.8964WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.5678 - categorical_accuracy: 0.8967 - val_loss: 0.8672 - val_categorical_accuracy: 0.6167
# Epoch 46/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5784 - categorical_accuracy: 0.8750WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 700ms/step - loss: 0.5718 - categorical_accuracy: 0.8833 - val_loss: 0.8604 - val_categorical_accuracy: 0.6417
# Epoch 47/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5649 - categorical_accuracy: 0.8929WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 733ms/step - loss: 0.5576 - categorical_accuracy: 0.9000 - val_loss: 0.8750 - val_categorical_accuracy: 0.6167
# Epoch 48/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5505 - categorical_accuracy: 0.8893WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 673ms/step - loss: 0.5568 - categorical_accuracy: 0.8833 - val_loss: 0.8710 - val_categorical_accuracy: 0.6250
# Epoch 49/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5510 - categorical_accuracy: 0.9000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 686ms/step - loss: 0.5463 - categorical_accuracy: 0.9033 - val_loss: 0.8577 - val_categorical_accuracy: 0.6417
# Epoch 50/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5339 - categorical_accuracy: 0.9107WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 10s 693ms/step - loss: 0.5427 - categorical_accuracy: 0.9033 - val_loss: 0.8793 - val_categorical_accuracy: 0.6083

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    except KeyError:
        plt.plot(history.history['categorical_accuracy'])
        plt.plot(history.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# You may notice overfitting in the above plots, through a growing discrepancy between the training and validation loss and accuracy. We will aim to mitigate this using data augmentation. Given our limited dataset, we may be able to improve the performance by applying random modifications to the images in the training data, effectively increasing the size of the dataset.

# %% [markdown]
# #### Create a new data generator with data augmentation
#
# You should now write a function to create a new `ImageDataGenerator` object, which performs the following data preprocessing and augmentation:
#
# * Scales the image pixel values by a factor of 1/255.
# * Randomly rotates images by up to 30 degrees
# * Randomly alters the brightness (picks a brightness shift value) from the range (0.5, 1.5)
# * Randomly flips images horizontally
#
# Hint: you may need to refer to the [documentation](https://keras.io/preprocessing/image/#imagedatagenerator-class) for the `ImageDataGenerator`.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_ImageDataGenerator_augmented():
    """
    This function should return an instance of the ImageDataGenerator class 
    with the above specifications.
    """
    return ImageDataGenerator(rescale=1/255, rotation_range=30, 
                              brightness_range=(0.5, 1.5), 
                              horizontal_flip=True
                             )

# %%
# Call the function to get an ImageDataGenerator as specified

image_gen_aug = get_ImageDataGenerator_augmented()

# %%
# Run this cell to define training and validation generators 

valid_generator_aug = get_generator(image_gen_aug, valid_dir)
train_generator_aug = get_generator(image_gen_aug, train_dir, seed=10)
# Out:
# Found 120 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
# Reset the original train_generator with the same random seed

train_generator = get_generator(image_gen, train_dir, seed=10)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Display sample augmented images and labels from the training set
#
# The following cell depends on your function `get_generator` to be implemented correctly. If it raises an error, go back and check the function specifications carefully.
#
# The cell will display augmented and non-augmented images (and labels) from the training dataset, using the `train_generator_aug` and `train_generator` objects defined above (if the images do not correspond to each other, check you have implemented the `seed` argument correctly).

# %%
# Display a few images and labels from the non-augmented and augmented generators

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])

aug_batch = next(train_generator_aug)
aug_batch_images = np.array(aug_batch[0])
aug_batch_labels = np.array(aug_batch[1])

plt.figure(figsize=(16,5))
plt.suptitle("Unaugmented images", fontsize=16)
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(batch_images[i])
    plt.title(lsun_classes[np.where(batch_labels[i] == 1.)[0][0]])
    plt.axis('off')
plt.figure(figsize=(16,5))
plt.suptitle("Augmented images", fontsize=16)
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(aug_batch_images[i])
    plt.title(lsun_classes[np.where(aug_batch_labels[i] == 1.)[0][0]])
    plt.axis('off')

# %%
# Reset the augmented data generator

train_generator_aug = get_generator(image_gen_aug, train_dir)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Train a new model on the augmented dataset

# %%
# Build and compile a new model

lsun_new_model = get_model((64, 64, 3))

# %%
# Train the model

history_augmented = train_model(lsun_new_model, train_generator_aug, valid_generator_aug, epochs=50)
# Out:
# Epoch 1/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0960 - categorical_accuracy: 0.3607WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 865ms/step - loss: 1.0966 - categorical_accuracy: 0.3567 - val_loss: 1.0932 - val_categorical_accuracy: 0.3917
# Epoch 2/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0919 - categorical_accuracy: 0.3750WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 826ms/step - loss: 1.0921 - categorical_accuracy: 0.3667 - val_loss: 1.0833 - val_categorical_accuracy: 0.5250
# Epoch 3/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0851 - categorical_accuracy: 0.4893WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 826ms/step - loss: 1.0853 - categorical_accuracy: 0.4900 - val_loss: 1.0747 - val_categorical_accuracy: 0.5667
# Epoch 4/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0681 - categorical_accuracy: 0.5429WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 806ms/step - loss: 1.0649 - categorical_accuracy: 0.5567 - val_loss: 1.0559 - val_categorical_accuracy: 0.5917
# Epoch 5/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0498 - categorical_accuracy: 0.4893WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 807ms/step - loss: 1.0490 - categorical_accuracy: 0.4967 - val_loss: 1.0160 - val_categorical_accuracy: 0.5833
# Epoch 6/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0235 - categorical_accuracy: 0.5643WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 813ms/step - loss: 1.0181 - categorical_accuracy: 0.5700 - val_loss: 1.0239 - val_categorical_accuracy: 0.5750
# Epoch 7/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9890 - categorical_accuracy: 0.6464WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 780ms/step - loss: 0.9916 - categorical_accuracy: 0.6433 - val_loss: 1.0107 - val_categorical_accuracy: 0.5500
# Epoch 8/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0172 - categorical_accuracy: 0.5429WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 820ms/step - loss: 1.0192 - categorical_accuracy: 0.5400 - val_loss: 1.0225 - val_categorical_accuracy: 0.5417
# Epoch 9/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9764 - categorical_accuracy: 0.6179WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 834ms/step - loss: 0.9798 - categorical_accuracy: 0.6100 - val_loss: 1.0014 - val_categorical_accuracy: 0.6083
# Epoch 10/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9994 - categorical_accuracy: 0.5857WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 846ms/step - loss: 0.9944 - categorical_accuracy: 0.5900 - val_loss: 1.0083 - val_categorical_accuracy: 0.5500
# Epoch 11/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9613 - categorical_accuracy: 0.6321WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 847ms/step - loss: 0.9597 - categorical_accuracy: 0.6300 - val_loss: 0.9745 - val_categorical_accuracy: 0.5917
# Epoch 12/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9462 - categorical_accuracy: 0.6607WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 893ms/step - loss: 0.9505 - categorical_accuracy: 0.6533 - val_loss: 0.9720 - val_categorical_accuracy: 0.6000
# Epoch 13/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9638 - categorical_accuracy: 0.6071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 846ms/step - loss: 0.9624 - categorical_accuracy: 0.6100 - val_loss: 0.9861 - val_categorical_accuracy: 0.5833
# Epoch 14/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9708 - categorical_accuracy: 0.6250WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 766ms/step - loss: 0.9718 - categorical_accuracy: 0.6167 - val_loss: 0.9869 - val_categorical_accuracy: 0.6000
# Epoch 15/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9437 - categorical_accuracy: 0.6500WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 800ms/step - loss: 0.9449 - categorical_accuracy: 0.6500 - val_loss: 0.9992 - val_categorical_accuracy: 0.5833
# Epoch 16/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9417 - categorical_accuracy: 0.6643WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 800ms/step - loss: 0.9417 - categorical_accuracy: 0.6667 - val_loss: 0.9725 - val_categorical_accuracy: 0.6167
# Epoch 17/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9532 - categorical_accuracy: 0.6179WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 787ms/step - loss: 0.9519 - categorical_accuracy: 0.6233 - val_loss: 0.9790 - val_categorical_accuracy: 0.6083
# Epoch 18/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9362 - categorical_accuracy: 0.6357WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 780ms/step - loss: 0.9334 - categorical_accuracy: 0.6400 - val_loss: 0.9837 - val_categorical_accuracy: 0.5500
# Epoch 19/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9253 - categorical_accuracy: 0.6607WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 780ms/step - loss: 0.9270 - categorical_accuracy: 0.6633 - val_loss: 0.9526 - val_categorical_accuracy: 0.6333
# Epoch 20/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9264 - categorical_accuracy: 0.6857WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 800ms/step - loss: 0.9173 - categorical_accuracy: 0.7000 - val_loss: 0.9420 - val_categorical_accuracy: 0.6250
# Epoch 21/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9061 - categorical_accuracy: 0.6893WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 820ms/step - loss: 0.9078 - categorical_accuracy: 0.6867 - val_loss: 0.9421 - val_categorical_accuracy: 0.6417
# Epoch 22/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8896 - categorical_accuracy: 0.6929WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 853ms/step - loss: 0.8922 - categorical_accuracy: 0.6833 - val_loss: 0.9450 - val_categorical_accuracy: 0.6167
# Epoch 23/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8897 - categorical_accuracy: 0.7143WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 827ms/step - loss: 0.8922 - categorical_accuracy: 0.7100 - val_loss: 0.9596 - val_categorical_accuracy: 0.5917
# Epoch 24/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8900 - categorical_accuracy: 0.6857WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 833ms/step - loss: 0.8922 - categorical_accuracy: 0.6867 - val_loss: 0.9458 - val_categorical_accuracy: 0.6167
# Epoch 25/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8931 - categorical_accuracy: 0.7036WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 820ms/step - loss: 0.8969 - categorical_accuracy: 0.7000 - val_loss: 0.9686 - val_categorical_accuracy: 0.6250
# Epoch 26/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8856 - categorical_accuracy: 0.7000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 860ms/step - loss: 0.8893 - categorical_accuracy: 0.6867 - val_loss: 0.9517 - val_categorical_accuracy: 0.6167
# Epoch 27/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8851 - categorical_accuracy: 0.6964WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 866ms/step - loss: 0.8871 - categorical_accuracy: 0.6967 - val_loss: 0.9529 - val_categorical_accuracy: 0.5917
# Epoch 28/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8779 - categorical_accuracy: 0.7000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 13s 847ms/step - loss: 0.8758 - categorical_accuracy: 0.7000 - val_loss: 0.9387 - val_categorical_accuracy: 0.6167
# Epoch 29/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8703 - categorical_accuracy: 0.7214WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 833ms/step - loss: 0.8733 - categorical_accuracy: 0.7167 - val_loss: 0.9429 - val_categorical_accuracy: 0.6250
# Epoch 30/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8601 - categorical_accuracy: 0.7321WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 833ms/step - loss: 0.8634 - categorical_accuracy: 0.7267 - val_loss: 0.9383 - val_categorical_accuracy: 0.6000
# Epoch 31/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8681 - categorical_accuracy: 0.7107WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 793ms/step - loss: 0.8727 - categorical_accuracy: 0.7100 - val_loss: 0.9286 - val_categorical_accuracy: 0.6167
# Epoch 32/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8644 - categorical_accuracy: 0.6929WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 766ms/step - loss: 0.8717 - categorical_accuracy: 0.6833 - val_loss: 0.9118 - val_categorical_accuracy: 0.6333
# Epoch 33/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8693 - categorical_accuracy: 0.7000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 760ms/step - loss: 0.8706 - categorical_accuracy: 0.6967 - val_loss: 0.9327 - val_categorical_accuracy: 0.6083
# Epoch 34/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8411 - categorical_accuracy: 0.7250WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 767ms/step - loss: 0.8397 - categorical_accuracy: 0.7300 - val_loss: 0.9459 - val_categorical_accuracy: 0.6167
# Epoch 35/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8756 - categorical_accuracy: 0.6750WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 773ms/step - loss: 0.8682 - categorical_accuracy: 0.6867 - val_loss: 0.9163 - val_categorical_accuracy: 0.6500
# Epoch 36/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8662 - categorical_accuracy: 0.6964WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 780ms/step - loss: 0.8703 - categorical_accuracy: 0.6933 - val_loss: 0.9066 - val_categorical_accuracy: 0.6417
# Epoch 37/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8364 - categorical_accuracy: 0.7179WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 787ms/step - loss: 0.8464 - categorical_accuracy: 0.7067 - val_loss: 0.9133 - val_categorical_accuracy: 0.6167
# Epoch 38/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8543 - categorical_accuracy: 0.7000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 773ms/step - loss: 0.8444 - categorical_accuracy: 0.7100 - val_loss: 0.8949 - val_categorical_accuracy: 0.6583
# Epoch 39/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8483 - categorical_accuracy: 0.6821WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 767ms/step - loss: 0.8489 - categorical_accuracy: 0.6833 - val_loss: 0.9024 - val_categorical_accuracy: 0.6083
# Epoch 40/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8617 - categorical_accuracy: 0.6964WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 780ms/step - loss: 0.8718 - categorical_accuracy: 0.6800 - val_loss: 0.9093 - val_categorical_accuracy: 0.5917
# Epoch 41/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8617 - categorical_accuracy: 0.6750WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 773ms/step - loss: 0.8519 - categorical_accuracy: 0.6867 - val_loss: 0.9244 - val_categorical_accuracy: 0.6083
# Epoch 42/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8426 - categorical_accuracy: 0.7036WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 767ms/step - loss: 0.8353 - categorical_accuracy: 0.7167 - val_loss: 0.9112 - val_categorical_accuracy: 0.6250
# Epoch 43/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8393 - categorical_accuracy: 0.7071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 787ms/step - loss: 0.8377 - categorical_accuracy: 0.7100 - val_loss: 0.9011 - val_categorical_accuracy: 0.6417
# Epoch 44/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8258 - categorical_accuracy: 0.7250WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 780ms/step - loss: 0.8256 - categorical_accuracy: 0.7267 - val_loss: 0.8864 - val_categorical_accuracy: 0.6333
# Epoch 45/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8460 - categorical_accuracy: 0.6857WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 780ms/step - loss: 0.8393 - categorical_accuracy: 0.6967 - val_loss: 0.8914 - val_categorical_accuracy: 0.6167
# Epoch 46/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8258 - categorical_accuracy: 0.7143WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 793ms/step - loss: 0.8289 - categorical_accuracy: 0.7100 - val_loss: 0.9191 - val_categorical_accuracy: 0.6250
# Epoch 47/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8249 - categorical_accuracy: 0.7179WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 800ms/step - loss: 0.8294 - categorical_accuracy: 0.7133 - val_loss: 0.8861 - val_categorical_accuracy: 0.6500
# Epoch 48/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8249 - categorical_accuracy: 0.7071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 766ms/step - loss: 0.8307 - categorical_accuracy: 0.7033 - val_loss: 0.8801 - val_categorical_accuracy: 0.6583
# Epoch 49/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8385 - categorical_accuracy: 0.7000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 11s 767ms/step - loss: 0.8355 - categorical_accuracy: 0.7067 - val_loss: 0.8782 - val_categorical_accuracy: 0.6417
# Epoch 50/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8530 - categorical_accuracy: 0.6607WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy,lr
# 15/15 [==============================] - 12s 773ms/step - loss: 0.8602 - categorical_accuracy: 0.6533 - val_loss: 0.9120 - val_categorical_accuracy: 0.6333

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history_augmented.history['accuracy'])
    plt.plot(history_augmented.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history_augmented.history['acc'])
        plt.plot(history_augmented.history['val_acc'])
    except KeyError:
        plt.plot(history_augmented.history['categorical_accuracy'])
        plt.plot(history_augmented.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history_augmented.history['loss'])
plt.plot(history_augmented.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# Do you see an improvement in the overfitting? This will of course vary based on your particular run and whether you have altered the hyperparameters.

# %% [markdown]
# #### Get predictions using the trained model

# %%
# Get model predictions for the first 3 batches of test data

num_batches = 3
seed = 25
test_generator = get_generator(image_gen_aug, test_dir, seed=seed)
predictions = lsun_new_model.predict_generator(test_generator, steps=num_batches)
# Out:
# Found 300 images belonging to 3 classes.

# %%
# Run this cell to view randomly selected images and model predictions

# Get images and ground truth labels
test_generator = get_generator(image_gen_aug, test_dir, seed=seed)
batches = []
for i in range(num_batches):
    batches.append(next(test_generator))
    
batch_images = np.vstack([b[0] for b in batches])
batch_labels = np.concatenate([b[1].astype(np.int32) for b in batches])

# Randomly select images from the batch
inx = np.random.choice(predictions.shape[0], 4, replace=False)
print(inx)

fig, axes = plt.subplots(4, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for n, i in enumerate(inx):
    axes[n, 0].imshow(batch_images[i])
    axes[n, 0].get_xaxis().set_visible(False)
    axes[n, 0].get_yaxis().set_visible(False)
    axes[n, 0].text(30., -3.5, lsun_classes[np.where(batch_labels[i] == 1.)[0][0]], 
                    horizontalalignment='center')
    axes[n, 1].bar(np.arange(len(predictions[i])), predictions[i])
    axes[n, 1].set_xticks(np.arange(len(predictions[i])))
    axes[n, 1].set_xticklabels(lsun_classes)
    axes[n, 1].set_title(f"Categorical distribution. Model prediction: {lsun_classes[np.argmax(predictions[i])]}")
    
plt.show()
# Out:
# Found 300 images belonging to 3 classes.
# [26 14 27 55]

# %% [markdown]
# Congratulations! This completes the first part of the programming assignment using the tf.keras image data processing tools.

# %% [markdown]
# ### Part 2: tf.data
#
# ![CIFAR-100 overview image](data/cifar100/cifar100.png)
#
# #### The CIFAR-100 Dataset

# %% [markdown]
# In the second part of this assignment, you will use the [CIFAR-100 dataset](https://www.cs.toronto.edu/~kriz/cifar.html). This image dataset has 100 classes with 500 training images and 100 test images per class.
#
# * A. Krizhevsky. "Learning Multiple Layers of Features from Tiny Images". April 2009
#
# Your goal is to use the tf.data module preprocessing tools to construct a data ingestion pipeline including filtering and function mapping over the dataset to train a neural network to classify the images.

# %% [markdown]
# #### Load the dataset

# %%
# Load the data, along with the labels

(train_data, train_labels), (test_data, test_labels) = cifar100.load_data(label_mode='fine')
with open('data/cifar100/cifar100_labels.json', 'r') as j:
    cifar_labels = json.load(j)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 2s 0us/step:

# %% [markdown]
# #### Display sample images and labels from the training set

# %%
# Display a few images and labels

plt.figure(figsize=(15,8))
inx = np.random.choice(train_data.shape[0], 32, replace=False)
for n, i in enumerate(inx):
    ax = plt.subplot(4, 8, n+1)
    plt.imshow(train_data[i])
    plt.title(cifar_labels[int(train_labels[i])])
    plt.axis('off')

# %% [markdown]
# #### Create Dataset objects for the train and test images
#
# You should now write a function to create a `tf.data.Dataset` object for each of the training and test images and labels. This function should take a numpy array of images in the first argument and a numpy array of labels in the second argument, and create a `Dataset` object.
#
# Your function should then return the `Dataset` object. Do not batch or shuffle the `Dataset` (this will be done later).

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def create_dataset(data, labels):
    """
    This function takes a numpy array batch of images in the first argument, and
    a corresponding array containing the labels in the second argument.
    The function should then create a tf.data.Dataset object with these inputs
    and outputs, and return it.
    """
    ds = tf.data.Dataset.from_tensor_slices((data, labels))
    return ds

# %%
# Run the below cell to convert the training and test data and labels into datasets

train_dataset = create_dataset(train_data, train_labels)
test_dataset = create_dataset(test_data, test_labels)

# %%
# Check the element_spec of your datasets

print(train_dataset.element_spec)
print(test_dataset.element_spec)
# Out:
# (TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))
# (TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))

# %% [markdown]
# #### Filter the Dataset
#
# Write a function to filter the train and test datasets so that they only generate images that belong to a specified set of classes.
#
# The function should take a `Dataset` object in the first argument, and a list of integer class indices in the second argument. Inside your function you should define an auxiliary function that you will use with the `filter` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a boolean indicating if the label is one of the allowed classes.
#
# Your function should then return the filtered dataset.
#
# **Hint:** you may need to use the [`tf.equal`](https://www.tensorflow.org/api_docs/python/tf/math/equal), [`tf.cast`](https://www.tensorflow.org/api_docs/python/tf/dtypes/cast) and [`tf.math.reduce_any`](https://www.tensorflow.org/api_docs/python/tf/math/reduce_any) functions in your auxiliary function.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def filter_classes(dataset, classes):
    """
    This function should filter the dataset by only retaining dataset elements whose
    label belongs to one of the integers in the classes list.
    The function should then return the filtered Dataset object.
    """
    def filter_auxiliary(image, label):
        return tf.math.reduce_any(tf.equal(label, classes))
    
    return dataset.filter(filter_auxiliary)

# %%
# Run the below cell to filter the datasets using your function

cifar_classes = [0, 29, 99] # Your datasets should contain only classes in this list

train_dataset = filter_classes(train_dataset, cifar_classes)
test_dataset = filter_classes(test_dataset, cifar_classes)

# %% [markdown]
# #### Apply map functions to the Dataset
#
# You should now write two functions that use the `map` method to process the images and labels in the filtered dataset.
#
# The first function should one-hot encode the remaining labels so that we can train the network using a categorical cross entropy loss.
#
# The function should take a `Dataset` object as an argument. Inside your function you should define an auxiliary function that you will use with the `map` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a tuple of two elements, with the unmodified image in the first element, and a one-hot vector in the second element. The labels should be encoded according to the following:
#
# * Class 0 maps to `[1., 0., 0.]`
# * Class 29 maps to `[0., 1., 0.]`
# * Class 99 maps to `[0., 0., 1.]`
#
# Your function should then return the mapped dataset.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def map_labels(dataset):
    """
    This function should map over the dataset to convert the label to a 
    one-hot vector. The encoding should be done according to the above specification.
    The function should then return the mapped Dataset object.
    """
    def map_auxiliary(image,label):
        if label == 0:
            return (image, tf.constant([1., 0., 0.]))
        elif label == 29:
            return (image, tf.constant([0., 1., 0.]))
        else:
            return (image, tf.constant([0., 0., 1.]))
        
    return dataset.map(map_auxiliary)

# %%
# Run the below cell to one-hot encode the training and test labels.

train_dataset = map_labels(train_dataset)
test_dataset = map_labels(test_dataset)

# %% [markdown]
# The second function should process the images according to the following specification:
#
# * Rescale the image pixel values by a factor of 1/255.
# * Convert the colour images (3 channels) to black and white images (single channel) by computing the average pixel value across all channels.
#
# The function should take a `Dataset` object as an argument. Inside your function you should again define an auxiliary function that you will use with the `map` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a tuple of two elements, with the processed image in the first element, and the unmodified label in the second argument.
#
# Your function should then return the mapped dataset.
#
# **Hint:** you may find it useful to use [`tf.reduce_mean`](https://www.tensorflow.org/api_docs/python/tf/math/reduce_mean?version=stable) since the black and white image is the colour-average of the colour images. You can also use the `keepdims` keyword in `tf.reduce_mean` to retain the single colour channel.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def map_images(dataset):
    """
    This function should map over the dataset to process the image according to the 
    above specification. The function should then return the mapped Dataset object.
    """
    def map_auxiliary(image, label):
        image = image/255
        image = tf.reduce_mean(image, axis = 2, keepdims = True)
        return image, label
    
    return dataset.map(map_auxiliary)

# %%
# Run the below cell to apply your mapping function to the datasets

train_dataset_bw = map_images(train_dataset)
test_dataset_bw = map_images(test_dataset)

# %% [markdown]
# #### Display a batch of processed images

# %%
# Run this cell to view a selection of images before and after processing

plt.figure(figsize=(16,5))
plt.suptitle("Unprocessed images", fontsize=16)
for n, elem in enumerate(train_dataset.take(10)):
    images, labels = elem
    ax = plt.subplot(2, 5, n+1)
    plt.title(cifar_labels[cifar_classes[np.where(labels == 1.)[0][0]]])
    plt.imshow(np.squeeze(images), cmap='gray')
    plt.axis('off')
    
plt.figure(figsize=(16,5))
plt.suptitle("Processed images", fontsize=16)
for n, elem in enumerate(train_dataset_bw.take(10)):
    images_bw, labels_bw = elem
    ax = plt.subplot(2, 5, n+1)
    plt.title(cifar_labels[cifar_classes[np.where(labels_bw == 1.)[0][0]]])
    plt.imshow(np.squeeze(images_bw), cmap='gray')
    plt.axis('off')

# %% [markdown]
# We will now batch and shuffle the Dataset objects.

# %%
# Run the below cell to batch the training dataset and expand the final dimensinos

train_dataset_bw = train_dataset_bw.batch(10)
train_dataset_bw = train_dataset_bw.shuffle(100)

test_dataset_bw = test_dataset_bw.batch(10)
test_dataset_bw = test_dataset_bw.shuffle(100)

# %% [markdown]
# #### Train a neural network model
#
# Now we will train a model using the `Dataset` objects. We will use the model specification and function from the first part of this assignment, only modifying the size of the input images.

# %%
# Build and compile a new model with our original spec, using the new image size
    
cifar_model = get_model((32, 32, 1))

# %%
# Train the model for 15 epochs

history = cifar_model.fit(train_dataset_bw, validation_data=test_dataset_bw, epochs=15)
# Out:
# Epoch 1/15
# 150/150 [==============================] - 22s 144ms/step - loss: 1.0909 - categorical_accuracy: 0.3793 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/15
# 150/150 [==============================] - 19s 127ms/step - loss: 1.0271 - categorical_accuracy: 0.5587 - val_loss: 0.9650 - val_categorical_accuracy: 0.6167
# Epoch 3/15
# 150/150 [==============================] - 19s 129ms/step - loss: 0.9498 - categorical_accuracy: 0.6327 - val_loss: 0.9177 - val_categorical_accuracy: 0.6267
# Epoch 4/15
# 150/150 [==============================] - 19s 128ms/step - loss: 0.8965 - categorical_accuracy: 0.6560 - val_loss: 0.8730 - val_categorical_accuracy: 0.6767
# Epoch 5/15
# 150/150 [==============================] - 19s 128ms/step - loss: 0.8590 - categorical_accuracy: 0.6767 - val_loss: 0.8607 - val_categorical_accuracy: 0.6500
# Epoch 6/15
# 150/150 [==============================] - 19s 128ms/step - loss: 0.8322 - categorical_accuracy: 0.7013 - val_loss: 0.8300 - val_categorical_accuracy: 0.6600
# Epoch 7/15
# 150/150 [==============================] - 19s 129ms/step - loss: 0.8048 - categorical_accuracy: 0.7027 - val_loss: 0.8028 - val_categorical_accuracy: 0.7033
# Epoch 8/15
# 150/150 [==============================] - 19s 129ms/step - loss: 0.7899 - categorical_accuracy: 0.7140 - val_loss: 0.7929 - val_categorical_accuracy: 0.7033
# Epoch 9/15
# 150/150 [==============================] - 23s 151ms/step - loss: 0.7745 - categorical_accuracy: 0.7193 - val_loss: 0.7963 - val_categorical_accuracy: 0.6700
# Epoch 10/15
# 150/150 [==============================] - 23s 152ms/step - loss: 0.7475 - categorical_accuracy: 0.7320 - val_loss: 0.7737 - val_categorical_accuracy: 0.7000
# Epoch 11/15
# 150/150 [==============================] - 23s 150ms/step - loss: 0.7446 - categorical_accuracy: 0.7347 - val_loss: 0.7616 - val_categorical_accuracy: 0.6833
# Epoch 12/15
# 150/150 [==============================] - 23s 151ms/step - loss: 0.7176 - categorical_accuracy: 0.7347 - val_loss: 0.7676 - val_categorical_accuracy: 0.7000
# Epoch 13/15
# 150/150 [==============================] - 23s 152ms/step - loss: 0.7078 - categorical_accuracy: 0.7427 - val_loss: 0.7334 - val_categorical_accuracy: 0.7133
# Epoch 14/15
# 150/150 [==============================] - 23s 151ms/step - loss: 0.6921 - categorical_accuracy: 0.7480 - val_loss: 0.7545 - val_categorical_accuracy: 0.7100
# Epoch 15/15
# 150/150 [==============================] - 23s 155ms/step - loss: 0.6851 - categorical_accuracy: 0.7553 - val_loss: 0.7234 - val_categorical_accuracy: 0.7300

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    except KeyError:
        plt.plot(history.history['categorical_accuracy'])
        plt.plot(history.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Create an iterable from the batched test dataset

test_dataset = test_dataset.batch(10)
iter_test_dataset = iter(test_dataset)

# %%
# Display model predictions for a sample of test images

plt.figure(figsize=(15,8))
inx = np.random.choice(test_data.shape[0], 18, replace=False)
images, labels = next(iter_test_dataset)
probs = cifar_model(tf.reduce_mean(tf.cast(images, tf.float32), axis=-1, keepdims=True) / 255.)
preds = np.argmax(probs, axis=1)
for n in range(10):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(images[n])
    plt.title(cifar_labels[cifar_classes[np.where(labels[n].numpy() == 1.0)[0][0]]])
    plt.text(0, 35, "Model prediction: {}".format(cifar_labels[cifar_classes[preds[n]]]))
    plt.axis('off')

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn to develop models for sequential data.
